# %% [raw]
# ---
# layout: post
# title: Nested Conditionals, Popcorn Hack Two
# description:  Second popcorn hack for nested conditionals
# type: issues
# comments: true
# ---

# %% [markdown]
# ### Popcorn Hack 2
#
# This code uses boolean to check if a person has the unlimited amusement food card. If they do, then they are allowed to buy any food that they want for free. Add code for another type of food and take into account whether or not the food is in stock.

# %%
# %%html
# <!-- HTML output div -->
# <div id="message"></div>
# <script>
#     function runWhenDOMLoaded() {
#         let foodCard = true;
#         let money = 1;
#         let foodChoice = "cotton candy"; //food choice 1
#         let cottonCandyInStock = false; //cotton candy is out of stock
#         let popcornInStock = true; //popcorn is in stock
#         let foodChoice2 = "funnel cake" //food choice 2
#         let funnelCakeInStock = true; //funnel cake is in stock
#         let iceCreamInStock = false; //ice cream is out of stock
#
#
#         const messageElement = document.getElementById("message");
#
#         function displayMessage(message) {
#             console.log(message); // Log to console
#             messageElement.textContent = message; // Display on the webpage
#         }
#
#         if (foodCard === true) {
#             if (foodChoice === "cotton candy") { //
#                 displayMessage("Cotton candy is a good choice! Let's see if it's in stock..."); //checks to see if cotton candy is in stock
#                 if (cottonCandyInStock === true) {
#                     displayMessage("Yay the cotton candy is in stock!");// prints this message
#                     displayMessage("Yum! The cotton candy is tasty!");
#                 } else if (cottonCandyInStock === false) {
#                     displayMessage("Sorry, cotton candy is out of stock. Choose something else!");
#                 }
#             }
#             if (foodChoice === "popcorn") {
#                 displayMessage("Popcorn is a good choice! Let's see if it's in stock...")
#                 if (popcornInStock === true) {
#                     displayMessage("Yay the popcorn is in stock!");//prints message for when popcorn is in stock
#                     displayMessage("Yum! The popcorn is tasty!");
#                 } else if (popcornInStock === false) {
#                     displayMessage("Sorry, popcorn is out of stock. Choose something else!");
#                 }
#             }
#             if (foodChoice2 === "funnel cake") {
#                 displayMessage("Funnel cake is a good choice! Let's see if it's in stock...")
#                 if (funnelCakeInStock === true) {
#                     displayMessage("Yay the funnel cake is in stock!");//Checks the food choice
#                     displayMessage("Yum! The funnel cake is tasty!");
#                 } else if (funnelCakeInStock === false) {
#                     displayMessage("Sorry, funnel cake is out of stock.");
#                 }
#             }
#             if (foodChoice2 === "ice cream") {
#                 displayMessage("Ice cream is a good choice! Let's see if it's in stock...")
#                 if (iceCreamInStock === true) {
#                     displayMessage("Yay the ice cream is in stock!");//Checks the food choice
#                     displayMessage("Yum! The ice cream is tasty!");
#                 } else if (iceCreamInStock === false) {
#                     displayMessage("Sorry, ice cream is out of stock.");
#                 }
#             }
#         } else {
#             if (foodChoice === "popcorn") {
#                 if (money >= 8) { // checks if you have enough money to buy
#                     //Add another if statement to check if the food is in stock!
#                     displayMessage("Yay! You can buy the popcorn!");
#                 } else {
#                     displayMessage("Oh... you can't buy the popcorn.");
#                 }
#             } else if (foodChoice === "cotton candy") {
#                 if (money >= 5) {
#                     //Add another if statement to check if the food is in stock!
#                     displayMessage("Yay! You can buy the cotton candy!");
#                 } else {
#                     displayMessage("Oh... you can't buy the cotton candy.");
#                 }//Add the other food and make sure to check if it is in stock!
#             }
#         }
#     }
#
#
#             //Use the previous code as examples to help make another food!
#             // Also, make sure to add more nested conditionals inside the if statements above to check if the food is in stock
#
#         // Ensure the function runs only after the page loads
#     if (document.readyState === "loading") {
#         document.addEventListener("DOMContentLoaded", runWhenDOMLoaded);
#     } else {
#        runWhenDOMLoaded();
#     }
#
#
# </script>
# Out:
# <!-- HTML output div -->
# <div id="message"></div>
# <script>
#     function runWhenDOMLoaded() {
#         let foodCard = true;
#         let money = 1;
#         let foodChoice = "cotton candy"; //food choice 1
#         let cottonCandyInStock = false; //cotton candy is out of stock
#         let popcornInStock = true; //popcorn is in stock
#         let foodChoice2 = "funnel cake" //food choice 2
#         let funnelCakeInStock = true; //funnel cake is in stock
#         let iceCreamInStock = false; //ice cream is out of stock
#
#
#         const messageElement = document.getElementById("message");
#
#         function displayMessage(message) {
#             console.log(message); // Log to console
#             messageElement.textContent = message; // Display on the webpage
#         }
#
#         if (foodCard === true) {
#             if (foodChoice === "cotton candy") { //
# ...
